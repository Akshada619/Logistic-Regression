# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
data = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
data.shape
# Out:
# (400, 5)

# %%
data.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
data.nunique()
# Out:
# User ID            400
# Gender               2
# Age                 43
# EstimatedSalary    117
# Purchased            2
# dtype: int64

# %%
data['Age'].unique()
# Out:
# array([19, 35, 26, 27, 32, 25, 20, 18, 29, 47, 45, 46, 48, 49, 31, 21, 28,
#        33, 30, 23, 24, 22, 59, 34, 39, 38, 37, 42, 40, 36, 41, 58, 55, 52,
#        60, 56, 53, 50, 51, 57, 44, 43, 54])

# %%
data['Age'].value_counts()
# Out:
# Age
# 35    32
# 37    20
# 26    16
# 41    16
# 42    16
# 39    15
# 40    15
# 48    14
# 47    14
# 27    13
# 38    13
# 28    12
# 36    12
# 46    12
# 31    11
# 30    11
# 49    10
# 29    10
# 33     9
# 32     9
# 24     9
# 59     7
# 19     7
# 45     7
# 20     7
# 60     7
# 34     6
# 23     6
# 52     6
# 25     6
# 58     6
# 53     5
# 57     5
# 22     5
# 18     5
# 21     4
# 50     4
# 54     4
# 55     3
# 56     3
# 51     3
# 43     3
# 44     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Age', data = data)
plt.show()

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Gender', data = data)
plt.show()

# %%
data['EstimatedSalary'].unique()
# Out:
# array([ 19000,  20000,  43000,  57000,  76000,  58000,  84000, 150000,
#         33000,  65000,  80000,  52000,  86000,  18000,  82000,  25000,
#         26000,  28000,  29000,  22000,  49000,  41000,  23000,  30000,
#         74000, 137000,  16000,  44000,  90000,  27000,  72000,  31000,
#         17000,  51000, 108000,  15000,  79000,  54000, 135000,  89000,
#         32000,  83000,  55000,  48000, 117000,  87000,  66000, 120000,
#         63000,  68000, 113000, 112000,  42000,  88000,  62000, 118000,
#         85000,  81000,  50000, 116000, 123000,  73000,  37000,  59000,
#        149000,  21000,  35000,  71000,  61000,  75000,  53000, 107000,
#         96000,  45000,  47000, 100000,  38000,  69000, 148000, 115000,
#         34000,  60000,  70000,  36000,  39000, 134000, 101000, 130000,
#        114000, 142000,  78000, 143000,  91000, 144000, 102000, 126000,
#        133000, 147000, 104000, 146000, 122000,  97000,  95000, 131000,
#         77000, 125000, 106000, 141000,  93000, 138000, 119000, 105000,
#         99000, 129000,  46000,  64000, 139000])

# %%
data['EstimatedSalary'].value_counts()
# Out:
# EstimatedSalary
# 72000     12
# 80000     11
# 79000     10
# 75000      9
# 71000      9
#           ..
# 123000     1
# 37000      1
# 115000     1
# 148000     1
# 139000     1
# Name: count, Length: 117, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='EstimatedSalary',data=data, palette='hls')
plt.show()

# %%
data['Purchased'].unique()
# Out:
# array([0, 1])

# %%
data['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Purchased', data=data, palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
cat_vars=['Purchased']
for var in cat_vars:
  cat_list='var'+'_'+var
cat_list =pd.get_dummies(data[var], prefix=var)
data1=data.join(cat_list)
data=data1

# %%
Purchased_high=pd.get_dummies(data["Purchased"], drop_first=True)
Purchased_high.head(7)
# Out:
#        1
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False

# %%
data2 = pd.concat([data,Purchased_high],axis=1)

# %%
data2
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  Purchased_0  \
# 0    15624510    Male   19            19000          0         True
# 1    15810944    Male   35            20000          0         True
# 2    15668575  Female   26            43000          0         True
# 3    15603246  Female   27            57000          0         True
# 4    15804002    Male   19            76000          0         True
# ..        ...     ...  ...              ...        ...          ...
# 395  15691863  Female   46            41000          1        False
# 396  15706071    Male   51            23000          1        False
# 397  15654296  Female   50            20000          1        False
# 398  15755018    Male   36            33000          0         True
# 399  15594041  Female   49            36000          1        False
#
#      Purchased_1      1
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ..           ...    ...
# 395         True   True
# 396         True   True
# 397         True   True
# 398        False  False
# 399         True   True
#
# [400 rows x 8 columns]

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  Purchased_0  \
# 0    15624510    Male   19            19000          0         True
# 1    15810944    Male   35            20000          0         True
# 2    15668575  Female   26            43000          0         True
# 3    15603246  Female   27            57000          0         True
# 4    15804002    Male   19            76000          0         True
# ..        ...     ...  ...              ...        ...          ...
# 395  15691863  Female   46            41000          1        False
# 396  15706071    Male   51            23000          1        False
# 397  15654296  Female   50            20000          1        False
# 398  15755018    Male   36            33000          0         True
# 399  15594041  Female   49            36000          1        False
#
#      Purchased_1
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 395         True
# 396         True
# 397         True
# 398        False
# 399         True
#
# [400 rows x 7 columns]

# %%
data.drop(data.columns[[3]], axis=1, inplace=True)
data.columns.values
# Out:
# array(['User ID', 'Gender', 'Age', 'Purchased', 'Purchased_0',
#        'Purchased_1'], dtype=object)

# %%
data.drop(data.columns[[2,3]], axis=1, inplace=True)
data.columns.values
# Out:
# array(['User ID', 'Gender', 'Purchased_0', 'Purchased_1'], dtype=object)

# %%
data
# Out:
#       User ID  Gender  Purchased_0  Purchased_1
# 0    15624510    Male         True        False
# 1    15810944    Male         True        False
# 2    15668575  Female         True        False
# 3    15603246  Female         True        False
# 4    15804002    Male         True        False
# ..        ...     ...          ...          ...
# 395  15691863  Female        False         True
# 396  15706071    Male        False         True
# 397  15654296  Female        False         True
# 398  15755018    Male         True        False
# 399  15594041  Female        False         True
#
# [400 rows x 4 columns]

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

print("X:\n", X)
print("y:\n", y)
# Out:
# X:
#        User ID  Gender  Purchased_0
# 0    15624510    Male         True
# 1    15810944    Male         True
# 2    15668575  Female         True
# 3    15603246  Female         True
# 4    15804002    Male         True
# ..        ...     ...          ...
# 395  15691863  Female        False
# 396  15706071    Male        False
# 397  15654296  Female        False
# 398  15755018    Male         True
# 399  15594041  Female        False
#
# [400 rows x 3 columns]
# y:
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: Purchased_1, Length: 400, dtype: bool

# %%
X = pd.get_dummies(data, columns=['Gender'], drop_first=True)
X = X.iloc[:, :-1]
y = data.iloc[:, -1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=0)
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
print('Logistic regression accuracy: {:.3f}'.format(accuracy_score(y_test,logreg.predict(X_test))))
# Out:
# Logistic regression accuracy: 1.000

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print('Random Forest Accuracy: {:.3f}'.format(accuracy_score(y_test,rf.predict(X_test))))
# Out:
# Random Forest Accuracy: 1.000

# %%
y_pred = rf.predict(X_test)
from sklearn.metrics import confusion_matrix
import seaborn as sns
forest_cm = metrics.confusion_matrix(y_pred, y_test)
sns.heatmap(forest_cm, annot=True, fmt='.2f',xticklabels = ["Left", "Stayed"] , yticklabels = ["Left", "Stayed"])
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Random Forest')
# Out:
# Text(0.5, 1.0, 'Random Forest')

# %%
logreg_y_pred = logreg.predict(X_test)
logreg_cm = metrics.confusion_matrix(y_test, logreg_y_pred)
sns.heatmap(logreg_cm, annot=True, fmt='.2f',
xticklabels = ["Left", "Stayed"] ,
yticklabels = ["Left", "Stayed"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
rf_roc_auc = roc_auc_score(y_test, rf.predict(X_test))
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
